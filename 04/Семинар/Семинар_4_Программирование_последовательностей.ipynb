# %% [markdown]
# # Семинар 4. Программирование последовательностей

# %% [markdown]
# ## Задача 1. Сумма положительных
#
# Дано `n`, затем `n` целых чисел. Найдите сумму всех положительных элементов.
#
# **Пример**
# ```text
# Ввод:
# 5
# -2
# 4
# 7
# 0
# -3
#
# Вывод:
# 11
# ```

# %%
# Решение

# %% [markdown]
# ## Задача 2. Количество элементов в диапазоне
#
# Дано `n`, затем `n` целых чисел и два числа `L` и `R`.
# Посчитайте количество элементов, принадлежащих отрезку `[L; R]`.

# %%
# Решение

# %% [markdown]
# ## Задача 3. Наибольший чётный элемент
#
# Найдите наибольший чётный элемент последовательности.
# Если чётных элементов нет, выведите `NO`.

# %%
# Решение

# %% [markdown]
# ## Задача 4. Минимум и количество его появлений
#
# Найдите минимальный элемент последовательности и количество раз, которое он встречается.

# %%
# Решение

# %% [markdown]
# ## Задача 5. Второй максимум среди различных значений
#
# Найдите второй по величине **различный** элемент последовательности.
# Гарантируется, что различных значений не меньше двух.

# %%
# Решение

# %% [markdown]
# ## Задача 6. Первый элемент, больший X
#
# Дано число `X`. Найдите номер первого элемента последовательности, который строго больше `X`.
# Если такого элемента нет, выведите `-1`.

# %%
# Решение

# %% [markdown]
# ## Задача 7. Последний отрицательный элемент
#
# Выведите значение и номер последнего отрицательного элемента.
# Если отрицательных элементов нет, выведите `NO`.

# %%
# Решение

# %% [markdown]
# ## Задача 8. Количество возрастаний
#
# Посчитайте количество пар соседних элементов, в которых правый элемент больше левого.

# %%
# Решение

# %% [markdown]
# ## Задача 9. Количество равных соседей
#
# Посчитайте количество пар соседних элементов с одинаковыми значениями.

# %%
# Решение

# %% [markdown]
# ## Задача 10. Максимальная разность соседей
#
# Найдите максимальное значение `|a[i] - a[i-1]|` и номер правого элемента соответствующей пары.

# %%
# Решение

# %% [markdown]
# ## Задача 11. Самый большой подъём
#
# Среди соседних пар найдите максимальное значение `a[i] - a[i-1]`.
# Разность может быть отрицательной.

# %%
# Решение

# %% [markdown]
# ## Задача 12. Смена знака
#
# Посчитайте, сколько раз знак меняется между соседними ненулевыми элементами.
# Если один из двух элементов равен нулю, такая пара не считается сменой знака.

# %%
# Решение

# %% [markdown]
# ## Задача 13. Самая длинная серия одинаковых элементов
#
# Найдите максимальное количество одинаковых элементов, идущих подряд.

# %%
# Решение

# %% [markdown]
# ## Задача 14. Самая длинная серия положительных
#
# Найдите максимальное количество положительных элементов, идущих подряд.

# %%
# Решение

# %% [markdown]
# ## Задача 15. Самая длинная возрастающая серия
#
# Найдите длину самого длинного непрерывного строго возрастающего фрагмента.

# %%
# Решение

# %% [markdown]
# ## Задача 16. Границы возрастающей серии
#
# Найдите номера первого и последнего элементов самой длинной строго возрастающей серии.
# Если таких серий несколько, выберите первую.

# %%
# Решение

# %% [markdown]
# ## Задача 17. Самая длинная серия с ограниченным шагом
#
# Найдите длину самого длинного фрагмента, в котором для каждой соседней пары выполняется
#
# \[
# 0 < a_i - a_{i-1} \le 5.
# \]

# %%
# Решение

# %% [markdown]
# ## Задача 18. Чередование знаков
#
# Найдите длину самого длинного непрерывного фрагмента из ненулевых чисел, в котором знаки соседних элементов чередуются.

# %%
# Решение

# %% [markdown]
# ## Задача 19. Локальные максимумы
#
# Посчитайте количество локальных максимумов:
#
# \[
# a_{i-1} < a_i > a_{i+1}.
# \]
#
# Первый и последний элементы не рассматриваются.

# %%
# Решение

# %% [markdown]
# ## Задача 20. Расстояние между локальными максимумами
#
# Найдите минимальное расстояние по индексам между двумя соседними локальными максимумами.
# Если локальных максимумов меньше двух, выведите `NO`.

# %%
# Решение

# %% [markdown]
# ## Задача 21. Лучшее окно длины 3
#
# Найдите максимальную сумму трёх подряд идущих элементов и номер первого элемента этого фрагмента.

# %%
# Решение

# %% [markdown]
# ## Задача 22. Лучшее окно длины k
#
# Даны `n`, `k` и последовательность из `n` чисел.
# Найдите максимальную сумму `k` подряд идущих элементов.
#
# Постарайтесь получить решение за `O(n)`.

# %%
# Решение

# %% [markdown]
# ## Задача 23. Первый повтор
#
# Дана последовательность целых чисел. Найдите первый элемент, который встретился повторно.
# Если повторов нет, выведите `NO`.

# %%
# Решение

# %% [markdown]
# ## Задача 24. Самое частое значение
#
# Найдите значение, которое встречается чаще всего.
# Если несколько значений имеют одинаковую максимальную частоту, выведите наименьшее из них.

# %%
# Решение

# %% [markdown]
# ## Задача 25. Максимальная сумма непрерывного фрагмента
#
# Найдите максимальную сумму непустого непрерывного фрагмента последовательности.
#
# **Дополнительный вопрос:** можно ли решить задачу за `O(n)` по времени и `O(1)` дополнительной памяти?

# %%
# Решение

# %% [markdown]
# ## Задача 26. Максимальная длина фрагмента с суммой не больше S
#
# Дана последовательность **неотрицательных** чисел и число `S`.
# Найдите максимальную длину непрерывного фрагмента, сумма элементов которого не превосходит `S`.
#
# Подумайте, как не пересчитывать сумму каждого фрагмента заново.

# %%
# Решение

# %% [markdown]
# ## Задача 27. Не более двух различных значений
#
# Найдите длину самого длинного непрерывного фрагмента, содержащего не более двух различных значений.

# %%
# Решение

# %% [markdown]
# ## Задача 28. Гора
#
# Найдите длину самой длинной «горы»: фрагмента длины хотя бы 3, который сначала строго возрастает, а затем строго убывает.
#
# Например:
#
# ```text
# 2 4 7 9 6 3
# ```
#
# — гора длины 6.

# %%
# Решение
